# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-18 11:20:58--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   149MB/s    in 0.5s
#
# 2022-06-18 11:21:00 (149 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df.sample(10)
# Out:
#                  id                                            summary   tag  \
# 19823   1207.4175v1  We consider the problem of estimating the dist...    cs
# 2828   1802.04325v1  Modern reinforcement learning algorithms reach...    cs
# 22797  1707.00102v1  When devising a course of treatment for a pati...  stat
# 8164    1405.1005v2  We discuss methodological issues related to th...    cs
# 12246  1710.10388v1  There has been a recent surge of interest in s...  stat
# 19522  cs/0612068v1  A product configurator which is complete, back...    cs
# 28568  1707.01058v2  This work make the first attempt to generate a...    cs
# 3991    0911.3209v1  To find all extreme points of multimodal funct...    cs
# 24037  1612.03094v1  Following the gaze of people inside videos is ...    cs
# 6050   1606.05596v1  It has been noticed that some external CVIs ex...  stat
#
#                                                    title  year  \
# 19823             On Modeling Profiles instead of Values  2012
# 2828   Efficient Model-Based Deep Reinforcement Learn...  2018
# 22797  Some methods for heterogeneous treatment effec...  2017
# 8164   Comparing apples to apples in the evaluation o...  2014
# 12246  Minimax Rates and Efficient Algorithms for Noi...  2017
# 19522  Interactive Configuration by Regular String Co...  2006
# 28568       Skeleton-aided Articulated Motion Generation  2017
# 3991   Apply Ant Colony Algorithm to Search All Extre...  2009
# 24037                        Following Gaze Across Views  2016
# 6050   Ground Truth Bias in External Cluster Validity...  2016
#
#                                                 keywords
# 19823  [estimating, distribution, underlying, likelih...
# 2828   [reinforcement, algorithms, performance, ineff...
# 22797  [treatment, quantitative, decisions, education...
# 8164   [methodological, evaluation, unsupervised, con...
# 12246  [permutation, comparison, structurally, parame...
# 19522  [configurator, backtrack, configuration, const...
# 28568  [articulated, including, information, embeddin...
# 3991   [multimodal, functions, difficult, optimizatio...
# 24037  [following, important, understanding, followin...
# 6050   [preferential, monotonic, candidate, partition...

# %%
df['keywords']
# Out:
# 22612    [distribution, probabilities, constructed, var...
# 40923    [introduce, algorithm, multiclass, classificat...
# 39523    [minimization, inference, graphical, notorious...
# 2303     [personalized, abandoning, dissatisfied, inter...
# 9663     [diffusion, resonance, tractography, anatomica...
#                                ...
# 21559    [variables, variables, structured, prediction,...
# 37286    [separation, minimization, minimizes, separati...
# 21982    [probabilistic, embedding, dimensional, dimens...
# 7179     [approximate, programming, algorithms, approxi...
# 17868    [constitute, understood, mechanisms, condition...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8783 words.
# Out of those 4635 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="16cb4a3d-759a-4ba7-af64-5e50b09a4a50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16cb4a3d-759a-4ba7-af64-5e50b09a4a50")) {                    Plotly.newPlot(                        "16cb4a3d-759a-4ba7-af64-5e50b09a4a50",                        [{"x":["distributions","automatically","maintaining","appropriate","probabilistic","parameters","distribution","statistics","gradients","assumption","probabilities","variables","construction","similarly","approximated","blockmodels","variational","procedure","minibatches","stochastic","applications","structure","constructed","inference","experiments","predictive","formulation","competitors","equilibrium","algorithm","performance","expressed","previously","multiclass","achieving","scalability","classification","introduce","theoretic","notoriously","formulations","including","application","existence","alternative","designing","reasonable","complexity","corresponding","approximation","approximate","computational","algorithms","graphical","intractable","consisting","minimization","exponential","specifically","approximations","researchers","polynomial","tractable","personalized","interested","scenarios","investigate","interacting","heterogeneity","furthermore","population","efficiently","personalization","thresholded","personalizing","guarantees","transformation","necessary","tractography","tractographies","anatomical","optimization","diffusion","reformulate","differences","registration","correspond","annealing","techniques","simulated","structures","combinatorial","segmentation","performed","transform","preliminary","resonance","similarities","streamline","resulting","volumetric","promising","implemented","implementation","essential","extracting","substantially","reduction","fingerprints","technique","flexibility","clustering","illustrate","metabolic","particular","accuracies","guideline","generating","successfully","dimensional","collection","dimensionality","numerical","topological","processes","important","classifying","properties","soundness","separation","correctness","developed","probability","identifies","independencies","completeness","efficient","belonging","frequencies","documents","clustered","execution","represented","significantly","respective","represent","normalized","categories","extensive","direction","hippocampal","convolutional","different","structural","modalities","extraction","automatic","balancing","impairment","tomography","prodromal","initiative","supervised","functional","diagnosis","neuroimaging","framework","diagnostics","approaches","comparison","determination","alzheimer","augmentation","alzheimers","cognitive","demonstrate","conditions","applicable","functions","estimation","beneficial","representations","information","complementary","intensity","disparate","centimeter","resilience","resolution","measurements","autonomous","adaptively","uncertainty","importantly","innovative","robustness","comprehensively","localization","challenging","effectiveness"],"y":[133,168,34,76,143,235,236,61,31,69,57,122,79,23,19,0,51,121,1,130,417,335,51,207,621,54,89,6,18,801,892,36,107,8,87,38,535,354,43,4,19,242,254,39,91,54,27,202,143,116,111,284,563,53,30,53,73,47,165,40,69,69,33,16,30,111,151,17,5,187,54,150,1,0,2,54,54,69,1,0,15,303,20,3,46,27,24,11,368,55,135,42,191,110,60,45,18,42,2,155,12,121,108,132,71,52,36,90,6,247,27,173,68,1,282,20,2,79,90,192,83,46,76,22,86,338,39,220,6,22,18,200,187,19,1,20,381,20,20,71,16,34,93,244,23,127,23,69,167,69,3,387,788,64,44,142,197,11,6,23,1,6,219,37,47,4,562,4,442,152,12,4,31,5,60,541,142,53,213,201,28,219,708,37,35,6,2,4,101,41,48,20,80,36,14,88,6,60,256,206],"type":"bar"},{"x":["distributions","automatically","maintaining","appropriate","pr ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4635,), (4635, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Standard</span> <span style=''>State</span> <span style=''>Space</span> <span style=''>Models</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unawareness</span> <span style=''>(Extended</span> <span style=''>Abstract)</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>impossibility</span> <span style=''>theorem</span> <span style=''>of</span> <span style=''>Dekel</span> <span style=''>Lipman</span> <span style=''>and</span> <span style=''>Rustichini</span> <span style=''>has</span> <span style=''>been</span> <span style=''>thought</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>standard</span> <span style=''>state</span> <span style=''>space</span> <span style=''>models</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.343915343915344);'>represent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unawareness</span> <span style=''>We</span> <span style=''>first</span> <span style=''>show</span> <span style=''>that</span> <span style=''>Dekel</span> <span style=''>Lipman</span> <span style=''>and</span> <span style=''>Rustichini</span> <span style=''>do</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>this</span> <span style=''>claim</span> <span style=''>We</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distinguish</span> <span style=''>three</span> <span style=''>notions</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636365);'>awareness</span> <span style=''>and</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>although</span> <span style=''>one</span> <span style=''>of</span> <span style=''>them</span> <span style=''>may</span> <span style=''>not</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adequately</span> <span style=''>modeled</span> <span style=''>using</span> <span style=''>standard</span> <span style=''>state</span> <span style=''>spaces</span> <span style=''>there</span> <span style=''>is</span> <span style=''>no</span> <span style=''>reason</span> <span style=''>to</span> <span style=''>think</span> <span style=''>that</span> <span style=''>standard</span> <span style=''>state</span> <span style=''>spaces</span> <span style=''>cannot</span> <span style=''>provide</span> <span style=''>models</span> <span style=''>of</span> <span style=''>the</span> <span style=''>other</span> <span style=''>two</span> <span style=''>notions</span> <span style=''>In</span> <span style=''>fact</span> <span style=''>standard</span> <span style=''>space</span> <span style=''>models</span> <span style=''>of</span> <span style=''>these</span> <span style=''>forms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636365);'>awareness</span> <span style=''>are</span> <span style=''>attractively</span> <span style=''>simple</span> <span style=''>They</span> <span style=''>allow</span> <span style=''>us</span> <span style=''>to</span> <span style=''>prove</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>completeness</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>decidability</span> <span style=''>results</span> <span style=''>with</span> <span style=''>ease</span> <span style=''>to</span> <span style=''>carry</span> <span style=''>over</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>from</span> <span style=''>decision</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>to</span> <span style=''>add</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Minimal</span> <span style=''>I</span> <span style=''>MAP</span> <span style=''>MCMC</span> <span style=''>for</span> <span style=''>Scalable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discovery</span> <span style=''>in</span> <span style=''>Causal</span> <span style=''>DAG</span> <span style=''>Models</span> <br/><br/><span style=''>Learning</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style=''>(BN)</span> <span style=''>from</span> <span style=''>data</span> <span style=''>can</span> <span style=''>be</span> <span style=''>useful</span> <span style=''>for</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovering</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>However</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>methods</span> <span style=''>often</span> <span style=''>fail</span> <span style=''>in</span> <span style=''>modern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>which</span> <span style=''>exhibit</span> <span style=''>a</span> <span style=''>larger</span> <span style=''>number</span> <span style=''>of</span> <span style=''>observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>than</span> <span style=''>data</span> <span style=''>points</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>network</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>the</span> <span style=''>desire</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommend</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>BN</span> <span style=''>but</span> <span style=''>the</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>BNs</span> <span style=''>poses</span> <span style=''>a</span> <span style=''>striking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>The</span> <span style=''>current</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style=''>order</span> <span style=''>MCMC</span> <span style=''>are</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>previous</span> <span style=''>methods</span> <span style=''>but</span> <span style=''>prevent</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>many</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style=''>priors</span> <span style=''>and</span> <span style=''>still</span> <span style=''>have</span> <span style=''>running</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scaling</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>Affinity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style=''>and</span> <span style=''>exploit</span> <span style=''>some</span> <span style=''>scaling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Affinity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <span style=''>(AP)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>proposed</span> <span style=''>by</span> <span style=''>Frey</span> <span style=''>and</span> <span style=''>Dueck</span> <span style=''>(2007)</span> <span style=''>First</span> <span style=''>we</span> <span style=''>observe</span> <span style=''>that</span> <span style=''>a</span> <span style=''>divide</span> <span style=''>and</span> <span style=''>conquer</span> <span style=''>strategy</span> <span style=''>used</span> <span style=''>on</span> <span style=''>a</span> <span style=''>large</span> <span style=''>data</span> <span style=''>set</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchically</span> <span style=''>reduces</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>cal</span> <span style=''>O(N2)</span> <span style=''>to</span> <span style=''>cal</span> <span style=''>O(N(h2)(h1))</span> <span style=''>for</span> <span style=''>a</span> <span style=''>data</span> <span style=''>set</span> <span style=''>of</span> <span style=''>size</span> <span style=''>N</span> <span style=''>and</span> <span style=''>a</span> <span style=''>depth</span> <span style=''>h</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style=''>strategy</span> <span style=''>For</span> <span style=''>a</span> <span style=''>data</span> <span style=''>set</span> <span style=''>embedded</span> <span style=''>in</span> <span style=''>a</span> <span style=''>d</span> <span style='background-color:rgba(255, 0, 0, 0.31182795698924737);'>dimensional</span> <span style=''>space</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>is</span> <span style=''>obtained</span> <span style=''>without</span> <span style=''>notably</span> <span style=''>damaging</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3230769230769231);'>precision</span> <span style=''>except</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3048128342245988);'>dimension</span> <span style=''>d2</span> <span style=''>In</span> <span style=''>fact</span> <span style=''>for</span> <span style=''>d</span> <span style=''>larger</span> <span style=''>than</span> <span style=''>2</span> <span style=''>the</span> <span style=''>relative</span> <span style=''>loss</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3230769230769231);'>precision</span> <span style=''>scales</span> <span style=''>like</span> <span style=''>N(2</span> <span style=''>d)(h1)d</span> <span style=''>Finally</span> <span style=''>under</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>we</span> <span style=''>observe</span> <span style=''>that</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style=''>value</span> <span style=''>s</span> <span style=''>of</span> <span style=''>the</span> <span style=''>penalty</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficient</span> <span style=''>a</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style=''>TDA</span> <span style=''>Sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Realization</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Topological</span> <span style=''>Data</span> <span style=''>Analysis</span> <span style=''>for</span> <span style=''>Multi</span> <span style=''>Way</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Topological</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>(TDA)</span> <span style=''>has</span> <span style=''>emerged</span> <span style=''>as</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>promising</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruct</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>shapes</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>spaces</span> <span style=''>from</span> <span style=''>observed</span> <span style=''>data</span> <span style=''>samples</span> <span style=''>TDA</span> <span style=''>thus</span> <span style=''>yields</span> <span style=''>key</span> <span style=''>shape</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>descriptors</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>persistent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>topological</span> <span style=''>features</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style=''>task</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>multi</span> <span style=''>way</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>Sparse</span> <span style=''>sampling</span> <span style=''>on</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruct</span> <span style=''>signals</span> <span style=''>in</span> <span style=''>the</span> <span style=''>spatial</span> <span style=''>temporal</span> <span style=''>domain</span> <span style=''>from</span> <span style=''>just</span> <span style=''>a</span> <span style=''>few</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>carefully</span> <span style=''>chosen</span> <span style=''>samples</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Sparse</span> <span style=''>TDA</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>combines</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>favorable</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>the</span> <span style=''>two</span> <sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12950410274705673)
# 	experimental (0.12986086336068497)
# 	knowledge (0.131287905815198)
# 	information (0.25258651444880487)
# 	segmentation (0.06814127720299679)
# 	architecture (0.09097395647520513)
# 	detection (0.12343917231537638)
# 	recognition (0.13235818765608276)
# 	different (0.2811273635390653)
# 	convolutional (0.13806635747413484)
#
# Some Statistics words are:
# 	stochastic (0.13820731096644967)
# 	variables (0.13820731096644967)
# 	statistical (0.15222834251377065)
# 	theoretical (0.1542313470205308)
# 	estimation (0.1757636454682023)
# 	distribution (0.18828242363545317)
# 	algorithm (0.39659489233850775)
# 	dimensional (0.18327491236855284)
# 	inference (0.1942914371557336)
# 	regression (0.18377566349524285)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b192434d-ab4c-4ee8-87f3-997a78b3417a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b192434d-ab4c-4ee8-87f3-997a78b3417a")) {                    Plotly.newPlot(                        "b192434d-ab4c-4ee8-87f3-997a78b3417a",                        [{"x":["distributions","automatically","maintaining","appropriate","probabilistic","parameters","distribution","statistics","gradients","assumption","probabilities","variables","construction","similarly","approximated","blockmodels","variational","procedure","minibatches","stochastic","applications","structure","constructed","inference","experiments","predictive","formulation","competitors","equilibrium","algorithm","performance","expressed","previously","multiclass","achieving","scalability","classification","introduce","theoretic","notoriously","formulations","including","application","existence","alternative","designing","reasonable","complexity","corresponding","approximation","approximate","computational","algorithms","graphical","intractable","consisting","minimization","exponential","specifically","approximations","researchers","polynomial","tractable","personalized","interested","scenarios","investigate","interacting","heterogeneity","furthermore","population","efficiently","personalization","thresholded","personalizing","guarantees","transformation","necessary","tractography","tractographies","anatomical","optimization","diffusion","reformulate","differences","registration","correspond","annealing","techniques","simulated","structures","combinatorial","segmentation","performed","transform","preliminary","resonance","similarities","streamline","resulting","volumetric","promising","implemented","implementation","essential","extracting","substantially","reduction","fingerprints","technique","flexibility","clustering","illustrate","metabolic","particular","accuracies","guideline","generating","successfully","dimensional","collection","dimensionality","numerical","topological","processes","important","classifying","properties","soundness","separation","correctness","developed","probability","identifies","independencies","completeness","efficient","belonging","frequencies","documents","clustered","execution","represented","significantly","respective","represent","normalized","categories","extensive","direction","hippocampal","convolutional","different","structural","modalities","extraction","automatic","balancing","impairment","tomography","prodromal","initiative","supervised","functional","diagnosis","neuroimaging","framework","diagnostics","approaches","comparison","determination","alzheimer","augmentation","alzheimers","cognitive","demonstrate","conditions","applicable","functions","estimation","beneficial","representations","information","complementary","intensity","disparate","centimeter","resilience","resolution","measurements","autonomous","adaptively","uncertainty","importantly","innovative","robustness","comprehensively","localization","challenging","effectiveness","ambiguity","outperforming","simulations","recommendation","transportation","offerings","synthetic","confirming","embedding","activities","implicitly","empirical","predictions","logarithmic","preference","comparing","successes","estimator","categorization","explicitly","comparisons","collaboratively","accompanies","theoretical","fundamental","characterizes","crowdsourced","motivated","marketing","multinomial","individualized","deficiency","mechanism","predicting","improvements","prediction","adequately","morphologically","frequently","translation","architectures","vocabulary","effective","relatively","improvement","languages","morphological","adjusting","separately","orthogonal","granularity","considered","morphology", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	blockmodels
# 	thresholded
# 	tractographies
# 	accompanies
# 	bonferroni
# 	registers
# 	standardizing
# 	psychiatric
# 	semiparametric
# 	blockmodel
# 	memberships
# 	kronecker
# 	regressions
# 	particulars
# 	robustification
# 	kolmogorov
# 	traintest
# 	privately
# 	censoring
# 	prognostics
# Some words which never appear in Statistics papers:
# 	alzheimer
# 	centimeter
# 	morphologically
# 	primitive
# 	multinomials
# 	spontaneous
# 	expressing
# 	undertake
# 	wavelength
# 	devnagari
# 	modifiers
# 	happening
# 	recurrently
# 	participant
# 	fixations
# 	underlining
# 	semantical
# 	syntactically
# 	relativized
# 	propositional

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.061380682687892e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
